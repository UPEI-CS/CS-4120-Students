# %% [markdown]
# # Challenge 1: When a Straight Line Is Not Enough
#
# **How can we choose a model that captures the pattern in the data without simply choosing the most complicated model?**
#
# **Run this notebook:** In Colab, choose **File > Save a copy in Drive**. Work together through each checkpoint, from top to bottom. Run cells with Shift+Enter. Write and adapt code in the empty cells; add cells as needed. Running the supplied cells alone does not complete the challenge.
#
# This is a **75-minute group laboratory**. The notebook is your experimental record. Keep your code, plots, tables, cross-validation results and final test evaluation. Put your group's eight final answers in one Word document and submit it with the completed notebook in one ZIP to Moodle (see Checkpoint 8).
#
# The dataset loads automatically after publication. Before publication, upload `challenge-01-data.csv` in Colab's Files panel, or run locally from this notebook's folder. The release URL is defined once below.
#
# **Coding support:** Use the [code snippets](https://github.com/UPEI-CS/CS-4120-Students/blob/main/challenges/challenge-01/resources/code-snippets.md) for small syntax examples. Before publication, open the accompanying `resources/code-snippets.md` locally. You may ask your **AI partner** for syntax, debugging, loops, tables or library usage. Needing syntax help is expected; what matters is that your group assembles and understands the experiment, makes the decisions, and explains the evidence. Read suggested code, run it and check that it does what you intended.
#
# **Our working pattern:** question → group prediction → focused AI partner question when useful → write/adapt code → run the experiment → examine evidence → explain → next question.
#
# Use **TRACE** naturally: **Think**, **Request**, **Assess**, **Check**, **Explain**. Brief working notes are enough; no conversation transcript is required.

# %% [markdown]
# ## Checkpoint 1: Look at the data · 0–8 minutes
#
# Run the loading cell and inspect the variables. `x` is a unitless input and `y` a continuous unitless response in synthetic data. Write code for a scatterplot, using a snippet or your AI partner for syntax if needed.
#
# Before fitting anything, discuss:
# - Would you expect one straight line to describe this relationship well?
# - What would you look for after fitting the model to decide whether the straight line is missing something?
#
# **Group prediction:** _Write here before fitting._

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Update the release location here if necessary.
DATA_URL = "https://raw.githubusercontent.com/UPEI-CS/CS-4120-Students/main/challenges/challenge-01/data/challenge-01-data.csv"
LOCAL_CSV = Path("data/challenge-01-data.csv")
UPLOADED_CSV = Path("challenge-01-data.csv")
if LOCAL_CSV.exists():
    data = pd.read_csv(LOCAL_CSV)
elif UPLOADED_CSV.exists():
    data = pd.read_csv(UPLOADED_CSV)
else:
    data = pd.read_csv(DATA_URL)
assert list(data.columns) == ["x", "y"] and not data.isna().any().any()
display(data.head())
display(data.describe())

# %%
# Write your scatterplot code here.

# %% [markdown]
# **Evidence from the scatterplot:** _Describe what you see, without fitting a model yet._
#
# ## Checkpoint 2: Establish a baseline · 8–18 minutes
#
# Use the supplied fixed split so every group starts with the same partitions. **The test set is now closed until Checkpoint 7.** After the initial overview, use only training data to construct and compare models.
#
# **Group prediction:** _What do you expect from the fitted line and residuals?_
#
# Create and fit an ordinary linear regression baseline. Report training RMSE and R², plot the fitted relationship, and examine residuals. These training metrics describe fit, not performance on new data. Use snippets or ask your AI partner for syntax, then assemble the steps yourselves.

# %%
X = data[["x"]]
y = data["y"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)
# CLOSED: do not use X_test or y_test until Checkpoint 7.

# %%
# 1. Create a LinearRegression model.
# 2. Fit it using the training data.
# 3. Generate predictions on the training data.
# 4. Calculate RMSE and R².
# 5. Plot the fitted relationship.
# 6. Plot the residuals.

# %% [markdown]
# **Examine the evidence:** What pattern do you see in the residuals? If the model captured the relationship well, what would you expect the residuals to look like?
#
# **Group observations:** _Write here._
#
# ### AI partner interaction 1
#
# Observe first. Use this prompt to investigate the curved pattern you are looking for, and assess whether its premise matches your own residual plot:
#
# > My linear regression residuals show a curved pattern. I still want to use linear regression as the estimator. Is there a way to change how the input features are represented so the model can capture curvature? Do not give me a complete solution. Help me understand the idea and decide what I should try next.
#
# **Assess and check:** What did the AI partner suggest? Why does it make sense based on your plot? Explain the idea in your own words before coding.

# %% [markdown]
# ## Checkpoint 3: Experiment with complexity · 18–30 minutes
#
# Your group has decided to investigate polynomial representations of `x`.
#
# **Group prediction:** _What do you expect to happen to training and validation error as the degree increases?_
#
# Create a fitting/validation split **from the training data only**, using `test_size=0.25` and `random_state=17`. Keep the outer test set closed.
#
# Investigate polynomial degrees **1 through 6**. For every degree:
# 1. Generate the polynomial features.
# 2. Fit linear regression.
# 3. Calculate training RMSE on the fitting portion.
# 4. Calculate validation RMSE.
# 5. Store the results so the degrees can be compared.
#
# Write the experiment and produce your own comparison table. Plot fitted relationships for selected degrees to understand what the extra complexity does. Ask your AI partner for help with individual steps, loop syntax or storing results as needed; check the resulting experiment yourselves.

# %% [markdown]
# **Examine the evidence:** What happens to training error as degree increases? Does the most complex model automatically give the best validation result? Which degree would you choose using only this split, and why?
#
# **Group provisional choice and evidence:** _Write here._
#
# ### AI partner interaction 2
#
# **Predict first:** _Could a different split change your ranking? Why?_
#
# > I chose a polynomial degree using one training/validation split. If I changed the random split, could my conclusion change? What experiment could I use to make this model comparison more reliable? Explain the reasoning before giving me code.
#
# **Assess and explain:** _What experiment was suggested? Why should it make the comparison more reliable?_

# %% [markdown]
# ## Checkpoint 4: Test the decision, not the test set · 30–43 minutes
#
# Now test your model choice using **5-fold cross-validation on the training data only**.
#
# **Group prediction:** _Will your single-split choice still look best? Which models might depend most on the held-out rows?_
#
# Build the experiment with:
# - five folds;
# - `shuffle=True`;
# - `random_state=42`;
# - degrees 1 through 6, evaluated on the same folds;
# - RMSE for every fold;
# - mean RMSE for each degree;
# - standard deviation across fold RMSEs for each degree (use `ddof=1` for a consistent classroom comparison).
#
# Fit each fold independently. Write code to record the scores and make your own table. Use the AI partner or snippets for syntax support; do not use the test set.

# %% [markdown]
# **Examine the evidence:** Is your single-split choice still your choice? Are some models more variable across folds? Why care about both average performance and variability? Look at the individual fold results as well as the summary.
#
# **Group interpretation:** _Write here. Fold standard deviation describes spread; it is not a confidence interval or proof that one model is significantly better._

# %% [markdown]
# ## Checkpoint 5: Keeping the modelling steps together · 43–55 minutes
#
# You now have several modelling steps. You create polynomial features, may transform those features, and then fit the model. During cross-validation, each fold must be treated independently.
#
# **Group prediction:** What could go wrong if a transformation learns information using the validation fold?
#
# _Write your reasoning here before asking your AI partner._
#
# ### AI partner interaction 3
#
# > My model now requires transformations before linear regression, and I am evaluating it using cross-validation. When cross-validation creates each training fold and validation fold, when should those transformations be learned? Is there a scikit-learn tool that can keep the transformations and model together as one modelling workflow? Explain why this matters before showing me how to use it.
#
# **Assess and explain:** _What tool did your AI partner suggest? Why would it help? Which steps learn information from observed data, and which are fixed by your choices?_

# %% [markdown]
# ### After your conversation: construct the workflow
#
# Based on your investigation, build a modelling workflow that keeps the transformations and estimator together. Conceptually, include polynomial feature generation, scaling, and linear regression. You write the implementation with your AI partner's support. Import the tools you decide to use.
#
# Repeat your cross-validation experiment using the complete workflow for degrees 1 through 6. Produce your own fold results and mean/standard-deviation table.
#
# **Predict before running:** _Do you expect the scores to change? Why?_

# %% [markdown]
# **Check and explain:** _Compare your earlier CV evidence with the complete workflow. Investigate any unexpected difference. Explain when each transformation is fitted and how the same steps are applied when predicting new data._

# %% [markdown]
# ## Checkpoint 6: Make the decision · 55–60 minutes
#
# The test set must still be closed. Decide as a group:
# - Which degree are you choosing?
# - What evidence supports it, including CV RMSE and your plots?
# - What does the fold variability tell you?
# - Is any small improvement of a more complex model meaningful enough to justify that complexity?
#
# **Group decision and evidence:** _Write here. Record what test performance you expect before seeing it. Do not automatically choose a table's minimum without reasoning about the evidence._

# %%
# Record your chosen_degree here after agreeing on the evidence.

# %% [markdown]
# ## Checkpoint 7: Final evaluation · 60–68 minutes
#
# Now, and only now:
# 1. Fit your selected workflow using all training data.
# 2. Predict the untouched test set.
# 3. Calculate test RMSE.
# 4. Calculate test R².
# 5. Create a residual plot.
# 6. Compare the result with what you expected from cross-validation.
#
# Write this code yourselves by adapting the earlier code you built. **Evaluate your chosen model once; do not use this result to choose another degree.**
#
# **Before running:** _Confirm that your group has recorded its choice and expected performance above._

# %% [markdown]
# **Group interpretation:** _Is final test performance reasonably consistent with cross-validation? What would concern you? Support your answer with the metrics and residual plot. A 24-case test set will have sampling variation._

# %% [markdown]
# ## 8. Report back
#
# **68-75 minutes**
#
# Work together to answer the eight challenge questions in your group's Word document. Support your group answers with evidence from the completed notebook, including plots, RMSE values, cross-validation results, fold variability, and the final test evaluation.
#
# 1. Which polynomial degree did your group choose?
# 2. What evidence supports that choice?
# 3. Why was one training/validation split not enough to make the decision confidently?
# 4. What did the variation across the cross-validation folds tell you?
# 5. What problem does Pipeline help solve in this experiment?
# 6. What did your AI partner help clarify during the challenge?
# 7. After seeing the final test results, do you still think your model choice was reasonable? Explain using the evidence.
# 8. What is one thing your group would investigate next if you continued this experiment?
#
# ## Submission
#
# Submit one ZIP file per group to Moodle. The ZIP file should contain:
#
# - The group's completed Google Colab notebook (.ipynb), including code, plots, tables, cross-validation results, and final test evaluation.
# - One Word document (.docx) containing the group's answers to the eight challenge questions.
#
# At the top of the Word document include:
#
# > Challenge 1: When a Straight Line Is Not Enough
# > Group members:
# > Student IDs:
#
# Only one member of the group needs to submit the ZIP file.
#
# Provide one set of group answers; separate answers from every group member are not required.
#
# An AI partner transcript is not required. For the AI partner question, explain in your own words what the AI partner helped your group understand. Do not paste the conversation.
#
# ### Feedback for future challenges
#
# You will work in different teams in future challenges. The feedback you receive on this challenge will help you apply what you have learned in your next team.
